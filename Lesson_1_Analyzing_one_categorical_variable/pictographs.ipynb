# %% [markdown]
# # Reading pictographs

# %% [markdown]
# ## Blood Type Survey Results (Pictograph Analysis)
#
# ### 📊 Understanding the Pictograph
# - Each **blood drop icon** in the pictograph represents **8 people**.
# - To find the number of respondents for each blood type, multiply the number of drops by 8.
#
# ---
#
# ### 🧪 Example: A Positive
# - Count: 7 drops
# - Calculation: $7 \times 8 = 56$
# - **Result:** 56 respondents have type **A positive** blood.
#
# ---
#
# ### 🧪 O Positive
# - Count: 8 drops
# - Calculation: $8 \times 8 = 64$
# - **Result:** 64 respondents have type **O positive** blood.
#
# ---
#
# ### 🧪 O Negative
# - Count: 2 drops
# - Calculation: $2 \times 8 = 16$
# - **Result:** 16 respondents have type **O negative** blood.
#
# ---
#
# ### ✅ Final Answer
# - **64 respondents have type O positive blood.**
# - **16 respondents have type O negative blood.**

# %% [markdown]
# [Reading pictographs | Applying mathematical reasoning | Pre-Algebra | Khan Academy | YouTube](https://www.youtube.com/watch?v=qrVvpYt3Vl0&t=9s)

# %% [markdown]
# ![Question1.png](./IMAGES/pictographs/Question1.png)

# %% [markdown]
# ![Question2.png](./IMAGES/pictographs/Question2.png)

# %% [markdown]
# ![Question3.png](./IMAGES/pictographs/Question3.png)

# %% [markdown]
# ![Question4.png](./IMAGES/pictographs/Question4.png)

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/Content.md)
