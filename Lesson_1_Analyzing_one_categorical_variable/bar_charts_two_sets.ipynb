# %% [markdown]
# # Reading bar charts: comparing two sets of data

# %% [markdown]
# [Reading bar charts: comparing two sets of data | Pre-Algebra | Khan Academy | YouTube](https://www.youtube.com/watch?v=gnyHsgTFXIY)

# %% [markdown]
# ![Question1.png](./IMAGES/bar_charts_two_sets/Question1.png)

# %% [markdown]
# ![Question2.png](./IMAGES/bar_charts_two_sets/Question2.png)

# %% [markdown]
# ![Question3.png](./IMAGES/bar_charts_two_sets/Question3.png)

# %% [markdown]
# ![Question4.png](./IMAGES/bar_charts_two_sets/Question4.png)

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/Content.md)
