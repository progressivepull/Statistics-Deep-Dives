# %% [markdown]
# # Reading bar graphs

# %% [markdown]
# [Reading bar graphs | Applying mathematical reasoning | Pre-Algebra | Khan Academy | YouTube](https://www.youtube.com/watch?v=kiQ6MUQZHSs)

# %% [markdown]
# [Reading bar charts: basic example | Applying mathematical reasoning | Pre-Algebra | Khan Academy | YouTube](https://www.youtube.com/watch?v=9YjXGLWMvCM)

# %% [markdown]
# [Creating a bar chart | Applying mathematical reasoning | Pre-Algebra | Khan Academy | YouTube](https://www.youtube.com/watch?v=woUQ9LLaees&t=2s)

# %% [markdown]
# ![Question1.png](./IMAGES/bar_graphs/Question1.png)

# %% [markdown]
# ![Question2.png](./IMAGES/bar_graphs/Question2.png)

# %% [markdown]
# ![Question3.png](./IMAGES/bar_graphs/Question3.png)

# %% [markdown]
# ![Question4.png](./IMAGES/bar_graphs/Question4.png)

# %% [markdown]
# ![Question5.png](./IMAGES/bar_graphs/Question5.png)

# %% [markdown]
# ![Question6.png](./IMAGES/bar_graphs/Question6.png)

# %% [markdown]
# ![Question7.png](./IMAGES/bar_graphs/Question7.png)

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/Statistics_and_probability/Content.md)
