# %% [markdown]
# # Categorical data example

# %% [markdown]
# [Video games and violence | Statistical studies | Probability and Statistics | Khan Academy | YouTube](https://youtu.be/ahyWUV7AwKw)

# %% [markdown]
# # Lucio's Study on Violent Video Games and Fighting
#
# ## 📊 Fractions Table
#
# | Group                          | Fraction in a Fight | Fraction Not in a Fight |
# |--------------------------------|---------------------|--------------------------|
# | Play violent video games (5)   | 1/5                 | 4/5                      |
# | Don’t play violent video games (15) | 3/15 = 1/5          | 12/15 = 4/5              |
#
# ---
#
# ## 🔎 Interpretation
# - **Both groups show the same fraction (1/5)** of students in a fight.
# - **Both groups show the same fraction (4/5)** of students not in a fight.
# - Therefore, **there is no evidence of an association** between violent video games and fighting in Lucio’s sample.
#
# ---
#
# ## ⚖️ Conclusion
# Lucio’s small dataset suggests **no difference** between the two groups.
# Playing violent video games does **not appear to be linked to fighting** among his friends.
# However, because the sample size is limited, **larger studies would be needed** to draw stronger conclusions.

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/khan_academy/Content.md)
