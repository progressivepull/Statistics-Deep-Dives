# %% [markdown]
# # Review and intuition why we divide by n-1 for the unbiased sample variance

# %% [markdown]
# [Review and intuition why we divide by n-1 for the unbiased sample | Khan Academy | YouTube](https://www.youtube.com/watch?v=KkaU2ur3Ymw&t=1s)

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/khan_academy/Content.md)
