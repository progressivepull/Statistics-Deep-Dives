# %% [markdown]
# # Mean, median, & mode example

# %% [markdown]
# [Finding mean, median, and mode | Descriptive statistics | Probability and Statistics | Khan Academy | YouTube](https://www.youtube.com/watch?v=k3aKKasOmIw&t=12s)

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/Statistics_and_probability/Content.md)
