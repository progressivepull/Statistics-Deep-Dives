# %% [markdown]
# # Calculating percentile

# %% [markdown]
# [Calculating percentile | Modeling data distributions | AP Statistics | Khan Academy  | YouTube](https://www.youtube.com/watch?v=Ngyt8Q5tWkU&t=8s)

# %% [markdown]
# # [Context](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/khan_academy/Content.md)
