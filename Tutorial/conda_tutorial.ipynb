# %%
print("Hello Conda")
# Out:
# Hello Conda

# %% [markdown]
# # Change Folders
#
# ``` bash
# $ cd /D/GitHub-Progressive_Pull/Statistics-Deep-Dives
# ```

# %% [markdown]
# # 🧭 How to list Conda environments
#
# * **conda env list** — the most common command
# * **conda info --envs** — same output, just a different entry point
#
# Both will show something like:
#
# ``` bash
# $ conda env list
#
# # conda environments:
# #
# base                   C:\Users\cocon\anaconda3
#
# ```

# %% [markdown]
# # [README](https://github.com/progressivepull/Statistics-Deep-Dives/blob/main/README.md)
